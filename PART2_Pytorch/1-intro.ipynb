# %% [markdown]
# # Améliorer l'accuracy du modèle MedNIST

# %% [markdown]
# Tout d'abord, voici le record à battre :
# ![Capture%20d%E2%80%99%C3%A9cran%20du%202023-02-15%2016-25-05.png](attachment:Capture%20d%E2%80%99%C3%A9cran%20du%202023-02-15%2016-25-05.png)
#
# Dans sa version actuelle, le modèle atteint une accuracy de **99,43 %**.

# %% [markdown]
# Afin d'améliorer l'accuracy nous allons essayer ces différentes méthodes, dans cet ordre :
# - Générer de nouvelles données en faisant de l'augmentation d'images
# - Modifier la structure du CNN en ajoutant de nouvelles couches et en y intégrant du Dropout
# - Optimiser les hyperparamètres du modèle.
#
# Toutes ces approches sont testées et détaillées dans les notebooks suivants.
